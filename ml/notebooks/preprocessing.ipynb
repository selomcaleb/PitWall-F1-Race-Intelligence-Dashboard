# %%
import pandas as pd
from pathlib import Path

# base_dir = Path(__file__).resolve().parents[1]
# raw_dir = base_dir / "data" / "raw"
# raw_dir.mkdir(parents=True, exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 from pathlib import Path
#       3
# ----> 4 base_dir = Path(__file__).resolve().parents[1]
#       5 raw_dir = base_dir / "data" / "raw"
#       6 raw_dir.mkdir(parents=True, exist_ok=True)
#
# NameError: name '__file__' is not defined

# %%
laps_df = pd.read_csv("../data/raw/2025_monaco_race.csv")
laps_df.head()
# Out:
#                      Time Driver  DriverNumber                 LapTime  \
# 0  0 days 00:57:36.090000    VER             1  0 days 00:01:27.020000
# 1  0 days 00:59:22.408000    VER             1  0 days 00:01:46.318000
# 2  0 days 01:01:11.223000    VER             1  0 days 00:01:48.815000
# 3  0 days 01:02:51.513000    VER             1  0 days 00:01:40.290000
# 4  0 days 01:04:12.313000    VER             1  0 days 00:01:20.800000
#
#    LapNumber  Stint PitOutTime PitInTime             Sector1Time  \
# 0        1.0    1.0        NaN       NaN                     NaN
# 1        2.0    1.0        NaN       NaN  0 days 00:00:34.949000
# 2        3.0    1.0        NaN       NaN  0 days 00:00:32.110000
# 3        4.0    1.0        NaN       NaN  0 days 00:00:31.006000
# 4        5.0    1.0        NaN       NaN  0 days 00:00:21.744000
#
#               Sector2Time  ... FreshTyre             Team  \
# 0  0 days 00:00:38.394000  ...      True  Red Bull Racing
# ...

# %% [markdown]
# # Standardize Colums

# %%
# Driver → driver
# LapNumber → lap
# Stint → stint
# Compound → compound
# LapTime → lap_time
# Position → position
laps_df = laps_df.rename(columns={"Driver":"driver","DriverNumber":"driver_number", "LapNumber":"lap", "Stint":"stint", "Compound":"compound", "LapTime":"lap_time", "Position":"position"})

laps_df.head()
# Out:
#                      Time driver  driver_number                lap_time  lap  \
# 0  0 days 00:57:36.090000    VER              1  0 days 00:01:27.020000  1.0
# 1  0 days 00:59:22.408000    VER              1  0 days 00:01:46.318000  2.0
# 2  0 days 01:01:11.223000    VER              1  0 days 00:01:48.815000  3.0
# 3  0 days 01:02:51.513000    VER              1  0 days 00:01:40.290000  4.0
# 4  0 days 01:04:12.313000    VER              1  0 days 00:01:20.800000  5.0
#
#    stint PitOutTime PitInTime             Sector1Time             Sector2Time  \
# 0    1.0        NaN       NaN                     NaN  0 days 00:00:38.394000
# 1    1.0        NaN       NaN  0 days 00:00:34.949000  0 days 00:00:45.145000
# 2    1.0        NaN       NaN  0 days 00:00:32.110000  0 days 00:00:47.430000
# 3    1.0        NaN       NaN  0 days 00:00:31.006000  0 days 00:00:47.889000
# 4    1.0        NaN       NaN  0 days 00:00:21.744000  0 days 00:00:37.485000
#
# ...

# %% [markdown]
# # Detect pit stops

# %%
sorted_laps = laps_df.sort_values(by=['driver', 'lap'])
sorted_laps.head()

# for each driver compare stints
# Out:
#                        Time driver  driver_number                lap_time  \
# 428  0 days 00:57:40.549000    ALB             23  0 days 00:01:31.479000
# 429  0 days 00:59:32.701000    ALB             23  0 days 00:01:52.152000
# 430  0 days 01:01:21.047000    ALB             23  0 days 00:01:48.346000
# 431  0 days 01:02:57.053000    ALB             23  0 days 00:01:36.006000
# 432  0 days 01:04:17.518000    ALB             23  0 days 00:01:20.465000
#
#      lap  stint PitOutTime PitInTime             Sector1Time  \
# 428  1.0    1.0        NaN       NaN                     NaN
# 429  2.0    1.0        NaN       NaN  0 days 00:00:38.401000
# 430  3.0    1.0        NaN       NaN  0 days 00:00:30.845000
# 431  4.0    1.0        NaN       NaN  0 days 00:00:29.942000
# 432  5.0    1.0        NaN       NaN  0 days 00:00:21.014000
#
#                 Sector2Time  ... FreshTyre      Team            LapStartTime  \
# ...
